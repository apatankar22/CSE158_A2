# %%
import numpy as np
import sklearn
import pandas as pd

# %%
full_dataset = pd.read_csv("vehicles.csv")

# %%
full_dataset.isna().sum()
# Out:
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year              1205
# manufacturer     17646
# model             5277
# condition       174104
# cylinders       177678
# fuel              3013
# odometer          4400
# title_status      8242
# transmission      2556
# VIN             161042
# drive           130567
# size            306361
# type             92858
# paint_color     130203
# image_url           68
# description         70
# county          426880
# state                0
# lat               6549
# long              6549
# posting_date        68
# dtype: int64

# %%
full_dataset.price.value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>

# %%
full_dataset = full_dataset[full_dataset['price'] < 100000]

# %%
full_dataset.price.value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>

# %%
full_dataset = full_dataset[full_dataset['price'] > 1000]

# %%
full_dataset.price.value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>

# %%
full_dataset = full_dataset[full_dataset['year'] > 1950]

# %%
full_dataset.groupby('year')['price'].mean()
# Out:
# year
# 1951.0    15906.774194
# 1952.0    20040.495327
# 1953.0    15067.741935
# 1954.0    15956.329787
# 1955.0    27522.203883
#               ...
# 2018.0    30485.387350
# 2019.0    34238.254918
# 2020.0    37862.182061
# 2021.0    41378.426926
# 2022.0    17473.314286
# Name: price, Length: 72, dtype: float64

# %%
full_dataset.groupby('year')['price'].mean().plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# In order to preserve the size of the dataset, we tried to perform data imputation on the columns instead of simply deleting the rows with NaN values for these columns, which prevented the reduction of the size of our dataset by over half. However, ... Instead, we finally decided not to simply not use these columns in our predictions

# %% [markdown]
# In the year 2022, the price of used car prices on Craigslist seems to have dropped significantly; however, this is because there are relatively few datapoints in the dataset for new cars with a model year of 2022.

# %%
posting_date_not_na = full_dataset[full_dataset['posting_date'].notna()]
posting_year = posting_date_not_na['posting_date'].str[:4]

# %%
full_dataset['posting_year'] = posting_year

# %%
full_dataset['posting_year'].value_counts()
# Out:
# 2021    376289
# Name: posting_year, dtype: int64

# %% [markdown]
# Looks like all listings are from the year 2021

# %%
pd.DataFrame(full_dataset.groupby('odometer')['price'].mean()).reset_index().plot(kind = 'scatter', x = 'odometer', y = 'price', figsize = (20, 20))
# Out:
# <AxesSubplot:xlabel='odometer', ylabel='price'>

# %%
pd.DataFrame(full_dataset.odometer.value_counts().sort_index()).reset_index().plot(kind = 'scatter', x = 'index', y = 'odometer', figsize = (20, 20))
# Out:
# <AxesSubplot:xlabel='index', ylabel='odometer'>

# %%
full_dataset.year.value_counts().sort_index().plot(kind = 'bar', figsize = (20, 20))
# Out:
# <AxesSubplot:>

# %%
full_dataset = full_dataset.dropna(axis=1, how='all')

# %%
full_dataset = full_dataset.drop(columns = ['posting_date', 'state', 'image_url', 'paint_color', 'VIN', 'region_url', 'url'])

# %%
full_dataset = full_dataset[(full_dataset['manufacturer'].notna()) & (full_dataset['model'].notna())]

# %%
full_dataset
# Out:
#                 id   region  price    year manufacturer  \
# 27      7316814884   auburn  33590  2014.0          gmc
# 28      7316814758   auburn  22590  2010.0    chevrolet
# 29      7316814989   auburn  39590  2020.0    chevrolet
# 30      7316743432   auburn  30990  2017.0       toyota
# 31      7316356412   auburn  15000  2013.0         ford
# ...            ...      ...    ...     ...          ...
# 426875  7301591192  wyoming  23590  2019.0       nissan
# 426876  7301591187  wyoming  30590  2020.0        volvo
# 426877  7301591147  wyoming  34990  2020.0     cadillac
# 426878  7301591140  wyoming  28990  2018.0        lexus
# 426879  7301591129  wyoming  30590  2019.0          bmw
#
#                            model  condition    cylinders    fuel  odometer  \
# 27      sierra 1500 crew cab slt       good  8 cylinders     gas   57923.0
# 28                silverado 1500       good  8 cylinders     gas   71229.0
# ...

# %%
make_model = full_dataset['manufacturer'] + ' ' + full_dataset['model']

# %%
make_model
# Out:
# 27          gmc sierra 1500 crew cab slt
# 28              chevrolet silverado 1500
# 29         chevrolet silverado 1500 crew
# 30           toyota tundra double cab sr
# 31                        ford f-150 xlt
#                        ...
# 426875          nissan maxima s sedan 4d
# 426876    volvo s60 t5 momentum sedan 4d
# 426877         cadillac xt4 sport suv 4d
# 426878             lexus es 350 sedan 4d
# 426879      bmw 4 series 430i gran coupe
# Length: 404026, dtype: object

# %%
full_dataset['make+model'] = make_model

# %%
full_dataset['type'].value_counts()
# Out:
# sedan          84459
# SUV            75446
# pickup         42074
# truck          33138
# other          20525
# coupe          17624
# hatchback      15369
# wagon          10531
# van             8192
# convertible     7076
# mini-van        4666
# offroad          549
# bus              305
# Name: type, dtype: int64

# %%
full_dataset
# Out:
#                 id   region  price    year manufacturer  \
# 27      7316814884   auburn  33590  2014.0          gmc
# 28      7316814758   auburn  22590  2010.0    chevrolet
# 29      7316814989   auburn  39590  2020.0    chevrolet
# 30      7316743432   auburn  30990  2017.0       toyota
# 31      7316356412   auburn  15000  2013.0         ford
# ...            ...      ...    ...     ...          ...
# 426875  7301591192  wyoming  23590  2019.0       nissan
# 426876  7301591187  wyoming  30590  2020.0        volvo
# 426877  7301591147  wyoming  34990  2020.0     cadillac
# 426878  7301591140  wyoming  28990  2018.0        lexus
# 426879  7301591129  wyoming  30590  2019.0          bmw
#
#                            model  condition    cylinders    fuel  odometer  \
# 27      sierra 1500 crew cab slt       good  8 cylinders     gas   57923.0
# 28                silverado 1500       good  8 cylinders     gas   71229.0
# ...

# %%
len(make_model)
# Out:
# 404026

# %%
distinct_make_models = set(make_model)
len(distinct_make_models)
# Out:
# 24169

# %% [markdown]
# 1. Data imputation of missing size and drive values
# 2. Feature: Avg. price of used car given make/model and global avg. price if price not available in training data.

# %%
gmc_sierra = full_dataset[full_dataset['make+model'] == 'gmc sierra 1500 crew cab slt']

# %%
gmc_sierra[gmc_sierra['drive'].notna()].iloc[0]['drive']
# Out:
# '4wd'

# %%
len(gmc_sierra[gmc_sierra['drive'].notna()])
# Out:
# 46

# %%
full_dataset.isna().sum()
# Out:
# id                   0
# region               0
# price                0
# year                 0
# manufacturer         0
# model                0
# condition       164348
# cylinders       166951
# fuel              2553
# odometer          4137
# title_status      7718
# transmission      2271
# drive           120920
# size            290550
# type             84072
# description          2
# lat               6155
# long              6155
# make+model           0
# dtype: int64

# %%
global_avg_price = np.nanmean(full_dataset['price'])

# %%
global_avg_price
# Out:
# 19410.990358790717

# %%
avg_price_per_model =

# %%
make_model_sizes = {}
make_model_drive_types = {}
for i in distinct_make_models:
    if(i not in make_model_sizes):
        make_model_df = full_dataset[full_dataset['make+model'] == i]
        not_na_size_make_model_df = make_model_df[make_model_df['size'].notna()]
        if(len(not_na_size_make_model_df) == 0):
            vehicle_type = make_model_df[make_model_df['type'].notna()]
            same_type = 
            make_model_sizes[i] = 
        else:
            make_model_sizes[i] = make_model_df
